# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv(
    "Indicadores.csv",
    encoding="latin-1",
    sep=",",
    engine="python",
    skipinitialspace=True
)

# %%
df.head()
# Out:
#         ID  Riesgos Unidad auditable  Unnamed: 3 Código proceso  \
# 0      NaN      NaN              NaN         NaN            NaN
# 1      NaN      NaN              NaN         NaN            NaN
# 2  11331.0      NaN              NaN         NaN            NaN
# 3      NaN      NaN              NaN         NaN            NaN
# 4  11322.0      NaN              NaN         NaN            NaN
#
#                   Nombre proceso Clasificación objetivo estratégico  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2  Gestión Servicio de Urgencias                                NaN
# 3                            NaN                                NaN
# 4  Gestión Servicio de Urgencias                                NaN
#
#   Código objetivo estratégico Nombre objetivo estratégico  \
# 0                         NaN                         NaN
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Riesgos', 'Unidad auditable', 'Unnamed: 3', 'Código proceso',
#        'Nombre proceso', 'Clasificación objetivo estratégico',
#        'Código objetivo estratégico', 'Nombre objetivo estratégico',
#        'Indicador',
#        ...
#        'Febrero 2026', 'Unnamed: 1032', 'Unnamed: 1033', 'Unnamed: 1034',
#        'Unnamed: 1035', 'Marzo 2026', 'Unnamed: 1037', 'Unnamed: 1038',
#        'Unnamed: 1039', 'Unnamed: 1040'],
#       dtype='object', length=1041)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df = df.dropna(how='all')

# %%
columnas_base = [
    'ID',
    'Unidad auditable',
    'Código proceso',
    'Nombre proceso',
    'Indicador'
]

# %%
columnas_meses = [col for col in df.columns if any(mes in col for mes in [
    'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
    'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'
])]

# %%
df_melt = df.melt(
    id_vars=columnas_base,
    value_vars=columnas_meses,
    var_name='fecha',
    value_name='valor'
)

# %%
df_melt = df_melt.dropna(subset=['valor'])

# %%
df_melt['fecha'] = pd.to_datetime(df_melt['fecha'], errors='coerce')
# Out:
# C:\Users\nicoi\AppData\Local\Temp\ipykernel_9048\50693997.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_melt['fecha'] = pd.to_datetime(df_melt['fecha'], errors='coerce')

# %%
df_melt.head()
# Out:
#         ID               Unidad auditable Código proceso  \
# 0      NaN                            NaN            NaN
# 1  11331.0                            NaN            NaN
# 3  11322.0                            NaN            NaN
# 5  11324.0                            NaN            NaN
# 7  11305.0  Gestión Servicio de Urgencias            NaN
#
#                   Nombre proceso  \
# 0                            NaN
# 1  Gestión Servicio de Urgencias
# 3  Gestión Servicio de Urgencias
# 5  Gestión Servicio de Urgencias
# 7  Gestión Servicio de Urgencias
#
#                                            Indicador fecha         valor
# 0                                                NaN   NaT         Valor
# 1  PORCENTAJE DE INGRESOS EFECTIVOS AL HUS DE PAC...   NaT  Sin medición
# 3  PORCENTAJE DE PARTICIPACION DE REFERENCIA Y CO...   NaT  Sin medición
# 5  PORCENTAJE DE PERTINENCIA DE REMISIONES ACEPTA...   NaT  Sin medición
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# ID
# Riesgos
# Unidad auditable
# Código proceso
# Nombre proceso
# Clasificación objetivo estratégico
# Código objetivo estratégico
# Nombre objetivo estratégico
# Indicador
# Clasificación
# Código Indicador
# Tipo
# Estado
# Unidad de medida
# Periodicidad
# Responsable Análisis
# Responsable Operativo
# Finalidad
# Acumulación
# Tipo de semáforo
# Tipo de semaforización
# Escala (Rojo - Conservar rango)
# Escala (Verde - Conservar rango)
# Escala (Rojo - Conservar rango).1
# Escala (Rojo - Maximizar)
# Escala (Amarillo - Maximizar)
# Escala (Verde - Maximizar)
# Escala (Verde - Minimizar)
# Escala (Amarillo - Minimizar)
# Escala (Rojo - Minimizar)
# Tipo meta
# Clase
# Descripción
# Área
# ICONTEC
# Observación
# Criterios de calidad
# Descripción de uso
# Objetivos Institucionales
# Ejes de acreditación
# Modelo de atención
# Táctico
# Estratégico
# Operativo
# Aprobado Planeación
# Fórmula
# Fecha creación
# Fecha válido
# Fecha corte
# Referentes
# Relacionados
# Responsables
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('Escala')]
df = df.loc[:, ~df.columns.str.contains('Unnamed')]

# %%
columnas_base = [
    'ID',
    'Unidad auditable',
    'Código proceso',
    'Nombre proceso',
    'Indicador'
]

# %%
columnas_meses = [col for col in df.columns 
                  if any(mes in col for mes in [
                      'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
                      'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre'
                  ])]

# %%
df_melt = df.melt(
    id_vars=columnas_base,
    value_vars=columnas_meses,
    var_name='fecha',
    value_name='valor'
)

# %%
df_melt = df_melt[df_melt['valor'] != 'Sin medición']
df_melt = df_melt.dropna(subset=['valor'])

# %%
df_melt['fecha'] = pd.to_datetime(df_melt['fecha'], errors='coerce')
# Out:
# C:\Users\nicoi\AppData\Local\Temp\ipykernel_9048\50693997.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_melt['fecha'] = pd.to_datetime(df_melt['fecha'], errors='coerce')

# %%
df_melt['valor'] = pd.to_numeric(df_melt['valor'], errors='coerce')

# %%
df_melt.head()
# Out:
#      ID Unidad auditable Código proceso Nombre proceso Indicador fecha  valor
# 0   NaN              NaN            NaN            NaN       NaN   NaT    NaN
# 132 NaN              NaN            NaN            NaN       NaN   NaT    NaN
# 264 NaN              NaN            NaN            NaN       NaN   NaT    NaN
# 396 NaN              NaN            NaN            NaN       NaN   NaT    NaN
# 528 NaN              NaN            NaN            NaN       NaN   NaT    NaN

# %%
df = df.dropna(subset=['ID'])

# %%
df.head()
# Out:
#          ID  Riesgos               Unidad auditable Código proceso  \
# 2   11331.0      NaN                            NaN            NaN
# 4   11322.0      NaN                            NaN            NaN
# 6   11324.0      NaN                            NaN            NaN
# 8   11305.0      NaN  Gestión Servicio de Urgencias            NaN
# 10  11311.0      NaN  Gestión Servicio de Urgencias            NaN
#
#                    Nombre proceso Clasificación objetivo estratégico  \
# 2   Gestión Servicio de Urgencias                                NaN
# 4   Gestión Servicio de Urgencias                                NaN
# 6   Gestión Servicio de Urgencias                                NaN
# 8   Gestión Servicio de Urgencias                                NaN
# 10  Gestión Servicio de Urgencias                                NaN
#
#    Código objetivo estratégico Nombre objetivo estratégico  \
# 2                          NaN                         NaN
# ...

# %%
df_melt = df.melt(
    id_vars=[
        'ID',
        'Unidad auditable',
        'Código proceso',
        'Nombre proceso',
        'Indicador'
    ],
    value_vars=columnas_meses,
    var_name='fecha',
    value_name='valor'
)

# %%
df_melt = df_melt.dropna(subset=['valor'])
df_melt = df_melt[df_melt['valor'] != 'Sin medición']

# %%
df_melt.head()
# Out:
#          ID Unidad auditable Código proceso  \
# 848  4307.0              NaN    00PU01-V3,
# 849  4309.0              NaN    00PU01-V3,
# 851  4665.0              NaN    00PU01-V3,
# 869  4682.0              NaN    00PU01-V3,
# 871  4684.0              NaN    00PU01-V3,
#
#                                         Nombre proceso  \
# 848  Atención al Paciente de Urgencias, Gestión Ser...
# 849  Atención al Paciente de Urgencias, Gestión Ser...
# 851  Atención al Paciente de Urgencias, Gestión Ser...
# 869  Atención al Paciente de Urgencias, Gestión Ser...
# 871  Atención al Paciente de Urgencias, Gestión Ser...
#
#                                              Indicador       fecha     valor
# 848  PROPORCION DE PACIENTES QUE REINGRESAN AL SERV...  Enero 2011      0,00
# 849  PORCENTAJE DE MORTALIDAD EN URGENCIAS ANTES DE...  Enero 2011      1,15
# 851  PORCENTAJE MORTALIDAD OBSTETRICA EN URGENCIAS ...  Enero 2011      0,00
# ...

# %%
meses = {
    'Enero': '01', 'Febrero': '02', 'Marzo': '03',
    'Abril': '04', 'Mayo': '05', 'Junio': '06',
    'Julio': '07', 'Agosto': '08', 'Septiembre': '09',
    'Octubre': '10', 'Noviembre': '11', 'Diciembre': '12'
}

def convertir_fecha(fecha):
    try:
        mes, año = fecha.split()
        return f"{año}-{meses[mes]}-01"
    except:
        return None

df_melt['fecha'] = df_melt['fecha'].apply(convertir_fecha)
df_melt['fecha'] = pd.to_datetime(df_melt['fecha'])

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:123456@127.0.0.1:3304/hospital_kpi")

# %%
engine.connect()

# %%
df_melt.to_sql('mediciones', con=engine, if_exists='replace', index=False)
# Out:
# 5642

# %%
df_procesos = df_procesos.rename(columns={
    'Código proceso': 'codigo_proceso',
    'Nombre proceso': 'nombre_proceso'
})

# %%
df_procesos.columns
# Out:
# Index(['id_proceso', 'codigo_proceso', 'nombre_proceso'], dtype='object')

# %%
df_procesos.to_sql('procesos', con=engine, if_exists='append', index=False)
# Out:
# 2

# %%
df_indicadores = df[[
    'ID',
    'Indicador',
    'Código proceso',
    'Código objetivo estratégico',
    'Periodicidad',
    'Unidad de medida'
]].drop_duplicates()

# %%
df_indicadores = df_indicadores.dropna(subset=['ID', 'Indicador'])

# %%
df_indicadores = df_indicadores.rename(columns={
    'ID': 'id_indicador',
    'Indicador': 'nombre_indicador',
    'Periodicidad': 'frecuencia',
    'Unidad de medida': 'unidad'
})

# %%
df_indicadores = df_indicadores.merge(
    df_procesos[['codigo_proceso', 'id_proceso']],
    left_on='Código proceso',
    right_on='codigo_proceso',
    how='left'
)

# %%
df_indicadores = df_indicadores.drop(columns=['Código proceso', 'codigo_proceso'])

# %%
df_obj = df[[
    'Código objetivo estratégico',
    'Nombre objetivo estratégico'
]].drop_duplicates().dropna()

df_obj['id_objetivo'] = range(1, len(df_obj)+1)

df_obj = df_obj.rename(columns={
    'Código objetivo estratégico': 'codigo_objetivo',
    'Nombre objetivo estratégico': 'nombre_objetivo'
})

# %%
df_indicadores = df_indicadores.merge(
    df_obj[['codigo_objetivo', 'id_objetivo']],
    left_on='Código objetivo estratégico',
    right_on='codigo_objetivo',
    how='left'
)

# %%
df_indicadores = df_indicadores.drop(columns=[
    'Código objetivo estratégico',
    'codigo_objetivo'
])

# %%
df_indicadores['meta'] = None

# %%
df_indicadores = df_indicadores[[
    'id_indicador',
    'nombre_indicador',
    'id_proceso',
    'id_objetivo',
    'frecuencia',
    'meta',
    'unidad'
]]

# %%
df_indicadores['id_objetivo'] = df_indicadores['id_objetivo'].astype(int)
df_indicadores['id_proceso'] = df_indicadores['id_proceso'].astype(int)
df_indicadores['id_indicador'] = df_indicadores['id_indicador'].astype(int)

# %%
df_indicadores[['id_objetivo']].drop_duplicates()
# Out:
#     id_objetivo
# 7             1
# 8             2
# 9             4
# 13            3

# %%
df_indicadores.to_sql('indicadores', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
# ...

# %%
df_obj.head()
# Out:
#    codigo_objetivo                                    nombre_objetivo  \
# 16             ,,,  Atención centrada en el usuario,Oportunidad,Pr...
# 18             ,,,  Gestión clínica excelente y segura,Prestación ...
# 20              ,,  Integral (el manejo),Prestación de Servicios,E...
# 26             ,,,  Atención centrada en el usuario,Accesibilidad,...
#
#     id_objetivo
# 16            1
# 18            2
# 20            3
# 26            4

# %%
df_obj.to_sql('objetivos_estrategicos', con=engine, if_exists='append', index=False)
# Out:
# 4

# %%
df_indicadores = df_indicadores.drop_duplicates(subset=['id_indicador'])

# %%
df_indicadores.to_sql('indicadores', con=engine, if_exists='append', index=False)
# Out:
# 12

# %%
df_areas = df[['Unidad auditable']].drop_duplicates()

# %%
df_areas = df_areas.dropna()

# %%
df_areas = df_areas.rename(columns={
    'Unidad auditable': 'nombre_area'
})

# %%
df_areas['id_area'] = range(1, len(df_areas)+1)

# %%
df_areas = df_areas[['id_area', 'nombre_area']]

# %%
df_areas.head()
# Out:
#      id_area                        nombre_area
# 8          1      Gestión Servicio de Urgencias
# 117        2  Gestión Servicio de Urgencias UFZ

# %%
df_areas.to_sql('areas', con=engine, if_exists='append', index=False)
# Out:
# 2
